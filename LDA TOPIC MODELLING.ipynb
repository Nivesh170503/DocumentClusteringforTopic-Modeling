# %%
# Out:
# Topic 0:
# situation political tense growing economy
# Topic 1:
# movie blockbuster new machine learning
# Topic: 0
# Words: 0.077*"The" + 0.077*"is" + 0.075*"a" + 0.045*"wellness" + 0.045*"for" + 0.045*"happy" + 0.045*"life." + 0.045*"Health" + 0.045*"crucial" + 0.045*"blockbuster."
# Topic: 1
# Words: 0.058*"and" + 0.058*"are" + 0.058*"revolutionizing" + 0.058*"machine" + 0.058*"technology." + 0.058*"learning" + 0.058*"Intelligence" + 0.058*"Artificial" + 0.058*"economy" + 0.057*"growing"
